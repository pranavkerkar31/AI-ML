# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavkerkar31/AI-ML/blob/main/pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# Data Frames

# %%
data = {
    "names":["pranav","kerkar", "rahul", "rohit"],
    "age":[12,13,np.nan,19],
    "dept":["it","comp","mech","ecs"],
    "salary":[12000,13000,np.nan,20000]
}
data
# Out:
# {'names': ['pranav', 'kerkar', 'rahul', 'rohit'],
#  'age': [12, 13, nan, 19],
#  'dept': ['it', 'comp', 'mech', 'ecs'],
#  'salary': [12000, 13000, nan, 20000]}

# %%
df = pd.DataFrame(data)
df
# Out:
#     names   age  dept   salary
# 0  pranav  12.0    it  12000.0
# 1  kerkar  13.0  comp  13000.0
# 2   rahul   NaN  mech      NaN
# 3   rohit  19.0   ecs  20000.0

# %%
print(df.head(3))
print(df.tail(1))
# Out:
#     names   age  dept   salary
# 0  pranav  12.0    it  12000.0
# 1  kerkar  13.0  comp  13000.0
# 2   rahul   NaN  mech      NaN
#    names   age dept   salary
# 3  rohit  19.0  ecs  20000.0

# %%
df.iloc[0:3] # only the last value is not considered
# Out:
#     names   age  dept   salary
# 0  pranav  12.0    it  12000.0
# 1  kerkar  13.0  comp  13000.0
# 2   rahul   NaN  mech      NaN

# %%
df.loc[0:3] # all index values are considered
# Out:
#     names   age  dept   salary
# 0  pranav  12.0    it  12000.0
# 1  kerkar  13.0  comp  13000.0
# 2   rahul   NaN  mech      NaN
# 3   rohit  19.0   ecs  20000.0

# %%
print(df["age"]) # to access single col
print(df[["age",'dept']]) # two brackets for accessing two colouns
# Out:
# 0    12.0
# 1    13.0
# 2     NaN
# 3    19.0
# Name: age, dtype: float64
#     age  dept
# 0  12.0    it
# 1  13.0  comp
# 2   NaN  mech
# 3  19.0   ecs

# %%
# to drop the coloumn
df.drop("age",axis=1,inplace=True) # axis 1 means full coloum and axis 0 means first row, inplace tells to drop the col in the original table also.

# %%
print(df)
# Out:
#     names   age  dept   salary
# 0  pranav  12.0    it  12000.0
# 1  kerkar  13.0  comp  13000.0
# 2   rahul   NaN  mech      NaN
# 3   rohit  19.0   ecs  20000.0

# %%
print(df.shape)
print(df.info())
# Out:
# (4, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   names   4 non-null      object
#  1   dept    4 non-null      object
#  2   salary  3 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 228.0+ bytes
# None

# %% [markdown]
# Broadcasting

# %%
df['salary']=df['salary'] + 5000
df['salary']
# Out:
# 0    17000.0
# 1    18000.0
# 2        NaN
# 3    25000.0
# Name: salary, dtype: float64

# %% [markdown]
# Renaming coloumn

# %%
df.rename(columns = {'dept':"Department"},inplace = True)
print(df)
# Out:
#     names Department   salary
# 0  pranav         it  17000.0
# 1  kerkar       comp  18000.0
# 2   rahul       mech      NaN
# 3   rohit        ecs  25000.0

# %%
print(df['Department'].unique())
print(df['Department'].value_counts())
# Out:
# ['it' 'comp' 'mech' 'ecs']
# Department
# it      1
# comp    1
# mech    1
# ecs     1
# Name: count, dtype: int64

# %% [markdown]
# New Column

# %%
df['New Salary']=df['salary']*10
df
# Out:
#     names Department   salary  New Salary
# 0  pranav         it  17000.0    170000.0
# 1  kerkar       comp  18000.0    180000.0
# 2   rahul       mech      NaN         NaN
# 3   rohit        ecs  25000.0    250000.0

# %% [markdown]
# Data Cleaning

# %%
df.isnull().sum()
# Out:
# names         0
# Department    0
# salary        1
# New Salary    1
# dtype: int64

# %%
df.dropna()
# Out:
#     names Department   salary  New Salary
# 0  pranav         it  17000.0    170000.0
# 1  kerkar       comp  18000.0    180000.0
# 3   rohit        ecs  25000.0    250000.0

# %%
df1=pd.DataFrame(data)
df1
# Out:
#     names   age  dept   salary
# 0  pranav  12.0    it  12000.0
# 1  kerkar  13.0  comp  13000.0
# 2   rahul   NaN  mech      NaN
# 3   rohit  19.0   ecs  20000.0

# %%
# Replace null with zero
# df1.fillna(0) # very noob method, instead can do
df1['age'].fillna(df1['age'].mean())
# Out:
# 0    12.000000
# 1    13.000000
# 2    14.666667
# 3    19.000000
# Name: age, dtype: float64

# %% [markdown]
# Forward and Backward Fill

# %%
df1['age'].fillna(method = 'ffill') # also can use backward fill using 'bfill'
# Out:
# /tmp/ipython-input-2864520463.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1['age'].fillna(method = 'ffill')
# 0    12.0
# 1    13.0
# 2    13.0
# 3    19.0
# Name: age, dtype: float64

# %%
df1
# Out:
#     names   age  dept   salary
# 0  pranav  12.0    it  12000.0
# 1  kerkar  13.0  comp  13000.0
# 2   rahul   NaN  mech      NaN
# 3   rohit  19.0   ecs  20000.0

# %%
df1['names']=df1['names'].replace("rohit",'rahul')
df1
# Out:
#     names   age  dept   salary
# 0  pranav  12.0    it  12000.0
# 1  kerkar  13.0  comp  13000.0
# 2   rahul   NaN  mech      NaN
# 3   rahul  19.0   ecs  20000.0

# %% [markdown]
# Eliminating Duplicate Values

# %%
df_dup=df1[df1.duplicated(keep='first')] # the second repeated value is considered to be duplicate.
df1.drop_duplicates()

# %% [markdown]
# Eliminating Invalid Values

# %%
df1['salary'].apply(lambda x: x*10 if x>12000 else x)
# Out:
# 0     12000.0
# 1    130000.0
# 2         NaN
# 3    200000.0
# Name: salary, dtype: float64
