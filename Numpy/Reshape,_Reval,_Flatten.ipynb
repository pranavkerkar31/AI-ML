# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavkerkar31/AI-ML/blob/main/Reshape%2C_Reval%2C_Flatten.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reshape and Ravel

# %%
import numpy as np
arr=np.array([1,2,3,4,5,6])
reshaped = arr.reshape(2,3)
# reshaped2=reshaped.reshape(3,2)
reshaped
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# Reval

# %%
ravel = arr.ravel()
ravel          # convert the array to 1-D
# Out:
# array([1, 2, 3, 4, 5, 6])
