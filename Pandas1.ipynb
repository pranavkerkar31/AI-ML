# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavkerkar31/AI-ML/blob/main/Pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
a=pd.Series([10,20,30,40,50,60])
a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
a.dtype
a.values
a.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
a.name='Calories'
a.name
# Out:
# 'Calories'

# %% [markdown]
# Indexing

# %%
a[0:2]
# Out:
# 0    10
# 1    20
# Name: Calories, dtype: int64

# %% [markdown]
# Location based indexing

# %%
# using iloc
a.iloc[2]
a.iloc[[0,1,2]] # to fetch multiple values at index
# Out:
# np.int64(3)

# %%
fruits = ["apple",'banana','grapes','guava0','chiku','pineapple']
fruits
a.index=fruits
a
# Out:
# apple        10
# banana       20
# grapes       30
# guava0       40
# chiku        50
# pineapple    60
# Name: Calories, dtype: int64

# %%
a['apple']
# Out:
# np.int64(10)

# %% [markdown]
# Lable based Indexing

# %%
people_age = {
    "Rahul": 21,
    "Anita": 19,
    "Suresh": 25,
    "Priya": 22,
    "Amit": 24,
    "Neha": 20
}
series = pd.Series(people_age,name='Age')
series
# Out:
# Rahul     21
# Anita     19
# Suresh    25
# Priya     22
# Amit      24
# Neha      20
# Name: Age, dtype: int64

# %% [markdown]
# CONDITIONAL INDEXING

# %%
print(series>20)
series[series>20]
# Out:
# Rahul      True
# Anita     False
# Suresh     True
# Priya      True
# Amit       True
# Neha      False
# Name: Age, dtype: bool
# Rahul     21
# Suresh    25
# Priya     22
# Amit      24
# Name: Age, dtype: int64

# %% [markdown]
# Logical Operation

# %%
series[(series>20) & (series<30)]
# Out:
# Rahul     21
# Suresh    25
# Priya     22
# Amit      24
# Name: Age, dtype: int64

# %%
series['Rahul']=22 # modifying the colomn
series
# Out:
# Rahul     22
# Anita     19
# Suresh    25
# Priya     22
# Amit      24
# Neha      20
# Name: Age, dtype: int64
