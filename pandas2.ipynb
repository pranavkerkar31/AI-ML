# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavkerkar31/AI-ML/blob/main/pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# Data Frames

# %%
data = {
    "names":["pranav","kerkar", "rahul", "rohit"],
    "age":[12,13,np.nan,19],
    "dept":["it","comp","mech","ecs"],
    "salary":[12000,13000,np.nan,20000]
}
data
# Out:
# {'names': ['pranav', 'kerkar', 'rahul', 'rohit'],
#  'age': [12, 13, nan, 19],
#  'dept': ['it', 'comp', 'mech', 'ecs'],
#  'salary': [12000, 13000, nan, 20000]}

# %%
df = pd.DataFrame(data)
df
# Out:
#     names   age  dept   salary
# 0  pranav  12.0    it  12000.0
# 1  kerkar  13.0  comp  13000.0
# 2   rahul   NaN  mech      NaN
# 3   rohit  19.0   ecs  20000.0

# %%
print(df.head(3))
print(df.tail(1))
# Out:
#     names   age  dept   salary
# 0  pranav  12.0    it  12000.0
# 1  kerkar  13.0  comp  13000.0
# 2   rahul   NaN  mech      NaN
#    names   age dept   salary
# 3  rohit  19.0  ecs  20000.0

# %%
df.iloc[0:3] # only the last value is not considered
# Out:
#     names   age  dept   salary
# 0  pranav  12.0    it  12000.0
# 1  kerkar  13.0  comp  13000.0
# 2   rahul   NaN  mech      NaN

# %%
df.loc[0:3] # all index values are considered
# Out:
#     names   age  dept   salary
# 0  pranav  12.0    it  12000.0
# 1  kerkar  13.0  comp  13000.0
# 2   rahul   NaN  mech      NaN
# 3   rohit  19.0   ecs  20000.0

# %%
print(df["age"]) # to access single col
print(df[["age",'dept']]) # two brackets for accessing two colouns
# Out:
# 0    12.0
# 1    13.0
# 2     NaN
# 3    19.0
# Name: age, dtype: float64
#     age  dept
# 0  12.0    it
# 1  13.0  comp
# 2   NaN  mech
# 3  19.0   ecs

# %%
# to drop the coloumn
df.drop("age",axis=1,inplace=True) # axis 1 means full coloum and axis 0 means first row, inplace tells to drop the col in the original table also.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1203549147.py in <cell line: 0>()
#       1 # to drop the coloumn
# ----> 2 df.drop("age",axis=1,inplace=True) # axis 1 means full coloum and axis 0 means first row, inplace tells to drop the col in the original table also.
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['age'] not found in axis"

# %%
print(df)
# Out:
#     names   age  dept   salary
# 0  pranav  12.0    it  12000.0
# 1  kerkar  13.0  comp  13000.0
# 2   rahul   NaN  mech      NaN
# 3   rohit  19.0   ecs  20000.0

# %%
print(df.shape)
print(df.info())
# Out:
# (4, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   names   4 non-null      object
#  1   age     3 non-null      float64
#  2   dept    4 non-null      object
#  3   salary  3 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 260.0+ bytes
# None

# %% [markdown]
# Broadcasting

# %%
df['salary']=df['salary'] + 5000
df['salary']
# Out:
# 0    17000.0
# 1    18000.0
# 2        NaN
# 3    25000.0
# Name: salary, dtype: float64

# %% [markdown]
# Renaming coloumn

# %%
df.rename(columns = {'dept':"Department"},inplace = True)
print(df)
# Out:
#     names   age Department   salary
# 0  pranav  12.0         it  17000.0
# 1  kerkar  13.0       comp  18000.0
# 2   rahul   NaN       mech      NaN
# 3   rohit  19.0        ecs  25000.0

# %%
print(df['Department'].unique())
print(df['Department'].value_counts())
# Out:
# ['it' 'comp' 'mech' 'ecs']
# Department
# it      1
# comp    1
# mech    1
# ecs     1
# Name: count, dtype: int64

# %% [markdown]
# New Column

# %%
df['New Salary']=df['salary']*10
df
# Out:
#     names   age Department   salary  New Salary
# 0  pranav  12.0         it  17000.0    170000.0
# 1  kerkar  13.0       comp  18000.0    180000.0
# 2   rahul   NaN       mech      NaN         NaN
# 3   rohit  19.0        ecs  25000.0    250000.0
